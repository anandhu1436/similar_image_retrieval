# %%
import os
import numpy as np
import tensorflow as tf
from sklearn.neighbors import NearestNeighbors
from sub.IO_utils import read_imgs_dir
from sub.transform_utils import apply_transformer
from sub.transform_utils import resize_img, normalize_img
from sub.plot_utils import plot_query_retrieval
from sub.autoencoder import AutoEncoder

# Run mode: (autoencoder -> convAE) 
modelName = "convAE"  
trainModel = True
parallel = True  # use multicore processing

# Make paths for inputs
dataTrainDir = os.path.join(os.getcwd(), "data", "dataset")
dataTestDir = os.path.join(os.getcwd(), "data", "test")

outDir = os.path.join(os.getcwd(), "output")
if not os.path.exists(outDir):
    os.makedirs(outDir)

# Read images
extensions = [".jpg", ".jpeg"]
print("Reading train images from '{}'...".format(dataTrainDir))
imgs_train = read_imgs_dir(dataTrainDir, extensions, parallel=parallel)
print("Reading test images from '{}'...".format(dataTestDir))
imgs_test = read_imgs_dir(dataTestDir, extensions, parallel=parallel)
shape_img = (128,128,3)
print("Image shape = {}".format(shape_img))

# Build models


# Set up autoencoder
info = {
        "shape_img": shape_img,
        "autoencoderFile": os.path.join(outDir, "{}_autoecoder.h5".format(modelName)),
        "encoderFile": os.path.join(outDir, "{}_encoder.h5".format(modelName)),
        "decoderFile": os.path.join(outDir, "{}_decoder.h5".format(modelName)),
    }
model = AutoEncoder(modelName, info)
model.set_arch()

    
shape_img_resize = (128,128,3)
input_shape_model = tuple([int(x) for x in model.encoder.input.shape[1:]])
output_shape_model = tuple([int(x) for x in model.encoder.output.shape[1:]])
n_epochs = 25
    



# Print some model info
print("input_shape_model = {}".format(input_shape_model))
print("output_shape_model = {}".format(output_shape_model))

# Apply transformations to all images
class ImageTransformer(object):

    def __init__(self, shape_resize):
        self.shape_resize = shape_resize

    def __call__(self, img):
        img_transformed = resize_img(img, self.shape_resize)
        img_transformed = normalize_img(img_transformed)
        return img_transformed

transformer = ImageTransformer(shape_img_resize)
print("Applying image transformer to training images...")
imgs_train_transformed = apply_transformer(imgs_train, transformer, parallel=parallel)
print("Applying image transformer to test images...")
imgs_test_transformed = apply_transformer(imgs_test, transformer, parallel=parallel)

# Convert images to numpy array
X_train = np.array(imgs_train_transformed).reshape((-1,) + input_shape_model)
X_test = np.array(imgs_test_transformed).reshape((-1,) + input_shape_model)
print(" -> X_train.shape = {}".format(X_train.shape))
print(" -> X_test.shape = {}".format(X_test.shape))

# Train (if necessary)

if trainModel:
    model.compile(loss="binary_crossentropy", optimizer="adam")
    model.fit(X_train, n_epochs=n_epochs, batch_size=256)
    model.save_models()
else:
    model.load_models(loss="binary_crossentropy", optimizer="adam")

# Create embeddings using model
print("Inferencing embeddings using pre-trained model...")
E_train = model.predict(X_train)
E_train_flatten = E_train.reshape((-1, np.prod(output_shape_model)))
E_test = model.predict(X_test)
E_test_flatten = E_test.reshape((-1, np.prod(output_shape_model)))
print(" -> E_train.shape = {}".format(E_train.shape))
print(" -> E_test.shape = {}".format(E_test.shape))
print(" -> E_train_flatten.shape = {}".format(E_train_flatten.shape))
print(" -> E_test_flatten.shape = {}".format(E_test_flatten.shape))


# Fit kNN model on training images
print("Fitting k-nearest-neighbour model on training images...")
#change value of k , to retrieve k images
k=9
knn = NearestNeighbors(n_neighbors=k, metric="cosine")
knn.fit(E_train_flatten)

# Perform image retrieval on test images
print("Performing image retrieval on test images...")
for i, emb_flatten in enumerate(E_test_flatten):
    _, indices = knn.kneighbors([emb_flatten]) # find k nearest train neighbours
    img_query = imgs_test[i] # query image
    imgs_retrieval = [imgs_train[idx] for idx in indices.flatten()] # retrieval images
    outFile = os.path.join(outDir, "test_result_{}.png".format( i))
    plot_query_retrieval(img_query, imgs_retrieval, outFile)
# Out:
# Reading train images from '/content/data/dataset'...
# Reading test images from '/content/data/test'...
# Image shape = (128, 128, 3)
#
# autoencoder.summary():
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 8)         1160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 8)         584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 8)         584
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 8)         584
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 64, 16)        1168
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 128, 128, 3)       435
# =================================================================
# Total params: 4,963
# Trainable params: 4,963
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# encoder.summary():
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 8)         1160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 8)         584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 8)         0
# =================================================================
# Total params: 2,192
# Trainable params: 2,192
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# decoder.summary():
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 16, 16, 8)]       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 8)         584
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 8)         584
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 64, 64, 8)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 64, 16)        1168
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 128, 128, 3)       435
# =================================================================
# Total params: 2,771
# Trainable params: 2,771
# Non-trainable params: 0
# _________________________________________________________________
# None
# input_shape_model = (128, 128, 3)
# output_shape_model = (16, 16, 8)
# Applying image transformer to training images...
# Applying image transformer to test images...
#  -> X_train.shape = (140, 128, 128, 3)
#  -> X_test.shape = (3, 128, 128, 3)
# Epoch 1/25
# 1/1 [==============================] - 0s 347ms/step - loss: 0.6925 - val_loss: 0.6916
# Epoch 2/25
# 1/1 [==============================] - 0s 93ms/step - loss: 0.6916 - val_loss: 0.6906
# Epoch 3/25
# 1/1 [==============================] - 0s 99ms/step - loss: 0.6905 - val_loss: 0.6893
# Epoch 4/25
# 1/1 [==============================] - 0s 93ms/step - loss: 0.6893 - val_loss: 0.6879
# Epoch 5/25
# 1/1 [==============================] - 0s 93ms/step - loss: 0.6881 - val_loss: 0.6867
# Epoch 6/25
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6871 - val_loss: 0.6860
# Epoch 7/25
# 1/1 [==============================] - 0s 95ms/step - loss: 0.6865 - val_loss: 0.6853
# Epoch 8/25
# 1/1 [==============================] - 0s 93ms/step - loss: 0.6858 - val_loss: 0.6846
# Epoch 9/25
# 1/1 [==============================] - 0s 95ms/step - loss: 0.6849 - val_loss: 0.6841
# Epoch 10/25
# 1/1 [==============================] - 0s 93ms/step - loss: 0.6841 - val_loss: 0.6836
# Epoch 11/25
# 1/1 [==============================] - 0s 95ms/step - loss: 0.6835 - val_loss: 0.6832
# Epoch 12/25
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6829 - val_loss: 0.6826
# Epoch 13/25
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6822 - val_loss: 0.6817
# Epoch 14/25
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6813 - val_loss: 0.6805
# Epoch 15/25
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6803 - val_loss: 0.6794
# Epoch 16/25
# 1/1 [==============================] - 0s 95ms/step - loss: 0.6794 - val_loss: 0.6783
# Epoch 17/25
# 1/1 [==============================] - 0s 95ms/step - loss: 0.6784 - val_loss: 0.6772
# Epoch 18/25
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6771 - val_loss: 0.6762
# Epoch 19/25
# 1/1 [==============================] - 0s 95ms/step - loss: 0.6760 - val_loss: 0.6752
# Epoch 20/25
# 1/1 [==============================] - 0s 95ms/step - loss: 0.6749 - val_loss: 0.6739
# Epoch 21/25
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6735 - val_loss: 0.6726
# Epoch 22/25
# 1/1 [==============================] - 0s 100ms/step - loss: 0.6723 - val_loss: 0.6717
# Epoch 23/25
# 1/1 [==============================] - 0s 94ms/step - loss: 0.6712 - val_loss: 0.6710
# Epoch 24/25
# 1/1 [==============================] - 0s 98ms/step - loss: 0.6700 - val_loss: 0.6703
# Epoch 25/25
# 1/1 [==============================] - 0s 96ms/step - loss: 0.6690 - val_loss: 0.6692
# Saving models...
# Inferencing embeddings using pre-trained model...
#  -> E_train.shape = (140, 16, 16, 8)
#  -> E_test.shape = (3, 16, 16, 8)
#  -> E_train_flatten.shape = (140, 2048)
#  -> E_test_flatten.shape = (3, 2048)
# Fitting k-nearest-neighbour model on training images...
# Performing image retrieval on test images...

# %%
i=[232969]
while True:
    i.append(i*4592854)
